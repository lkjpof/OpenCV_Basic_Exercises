# %% [markdown]
# # Loading, Displaying and Saving
# ## Import the necessary packages

# %%
# %cd OpenCV_Basic_Exercises/
# !ls
# Out:
# /content/OpenCV_Basic_Exercises
# '10 - Gradients and Edge Detection.ipynb'
# '11 - Contours.ipynb'
# '3 - Loading, Displaying and Saving.ipynb'
# '4 - Image Basics.ipynb'
# '5 - Drawing.ipynb'
# '6.1 - Image Transformations.ipynb'
# '6.2 - Image Arithematic.ipynb'
# '6.3 - Bitwise Operations.ipynb'
# '6.4 - Masking.ipynb'
# '6.5 - Splitting and Merging Channels.ipynb'
# '6.6 - Color Spaces.ipynb'
# '7 - Histograms.ipynb'
# '8 - Smoothing and Blurring.ipynb'
# '9 - Thresholding.ipynb'
# 'Case Studies'
#  images
#  README.md

# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %% [markdown]
# ## Load the image and show some basic information on it

# %%
image = cv2.imread("images/image1.jpg")
print("width: {} pixels".format(image.shape[1]))
print("height: {} pixels".format(image.shape[0]))
print("channels: {}".format(image.shape[2]))
# Out:
# width: 350 pixels
# height: 228 pixels
# channels: 3

# %% [markdown]
# ## Show the image and wait for a keypress

# %%
plt.imshow(image)

# %% [markdown]
# ## Save the image
#
# Note: OpenCV handles converting filetypes automatically

# %%
cv2.imwrite("images/new_image1.jpg", image)
# Out:
# True
